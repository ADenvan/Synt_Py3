# %%
# Задача 1.
# Напишите программу, которая найдёт все числа, кратные 7, но не кратные 5, в диапазоне от 2000 до 3200 (включительно).
# Результат должен быть выведен в одну строку, числа разделены запятыми.

# Подсказка:
# Используйте функцию range(#start, #end) и оператор % для деления по модулю.
st = []
for i in range(2000, 3201):
  st.append(str(i))
log = ','.join(st)
print(log)
# Out:
# 2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030,2031,2032,2033,2034,2035,2036,2037,2038,2039,2040,2041,2042,2043,2044,2045,2046,2047,2048,2049,2050,2051,2052,2053,2054,2055,2056,2057,2058,2059,2060,2061,2062,2063,2064,2065,2066,2067,2068,2069,2070,2071,2072,2073,2074,2075,2076,2077,2078,2079,2080,2081,2082,2083,2084,2085,2086,2087,2088,2089,2090,2091,2092,2093,2094,2095,2096,2097,2098,2099,2100,2101,2102,2103,2104,2105,2106,2107,2108,2109,2110,2111,2112,2113,2114,2115,2116,2117,2118,2119,2120,2121,2122,2123,2124,2125,2126,2127,2128,2129,2130,2131,2132,2133,2134,2135,2136,2137,2138,2139,2140,2141,2142,2143,2144,2145,2146,2147,2148,2149,2150,2151,2152,2153,2154,2155,2156,2157,2158,2159,2160,2161,2162,2163,2164,2165,2166,2167,2168,2169,2170,2171,2172,2173,2174,2175,2176,2177,2178,2179,2180,2181,2182,2183,2184,2185,2186,2187,2188,2189,2190,2191,2192,2193,2194,2195,2196,2197,2198,219
# ...

# %%
# 🧩 Задача 2
# Уровень: 1 (Начальный)

# Условие:
# Напишите программу для вычисления факториала заданного числа.
# Допустим, на вход подаётся число: 8
# Результат: 40320

# Подсказка:
# Ввод предполагается с консоли. Используйте рекурсию.

def fact(n):
  if n == 0:
    return  1
  return n *  fact(n-1)
log = fact(8)
print(log)
# Out:
# 40320

# %%
# 🧩 Задача 3
# Уровень: 1 (Начальный)

# Условие:
# Напишите программу, которая с заданным числом n создаёт словарь вида {i: i*i} для всех i от 1 до n.
# Пример ввода: 8
# Результат: {1: 1, 2: 4, ..., 8: 64}

# Подсказка:
# Используйте dict() и цикл for.


def multy(n):
  d = dict()
  for i in range(1, n + 1):
    d[i] = i * i
  return d

log = multy(8)
print(log)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}

# %%
# 🧩 Задача 4
# Уровень: 1 (Начальный)

# Условие:
# Напишите программу, которая принимает последовательность чисел, разделённых запятыми, и создаёт из них список и кортеж.
# Пример ввода: 34,67,55,33,12,98
# Результат:
# Список: ['34', '67', '55', '33', '12', '98']
# Кортеж: ('34', '67', '55', '33', '12', '98')

# Подсказка:
# Используйте методы .split() и tuple().

def split_tuple(st: str):
  l = st.split(",")
  t = tuple(l)
  
st = "34,67,55,33,12,98"
log = split_tuple(st)
print(log)
# Out:
# (('34', '67', '55', '33', '12', '98'), ['34', '67', '55', '33', '12', '98'])

# %%
# 🧩 Задача 5
# Уровень: 1 (Начальный)

# Условие:
# Создайте класс с двумя методами:

# getString() — принимает строку из ввода;

# printString() — выводит строку в верхнем регистре.

# Протестируйте методы в коде.

# Подсказка:
# Используйте метод __init__ для инициализации.

class InputOutString(object):
  def __init__(self):
    self.s = ""

  def getString(self, st):
    self.s = st

  def printString(self):
    print (self.s.upper())

strObj = InputOutString()
strObj.getString("console log")
strObj.printString()
# Out:
# CONSOLE LOG

# %%
# ЗАДАЧА 6
# Уровень: Средний

# Условие:
# Напишите программу, которая вычисляет значения по формуле:
# Q = √[(2 * C * D) / H]
# Где:
# C = 50, H = 30 (заданы),
# D — вводимые значения (через запятую).

# Пример ввода: 100,150,180
# Результат: 18,22,24

# Подсказка:
# Округлите результат до ближайшего целого числа.

import math

def exemp(inp):
  c = 50
  h = 30
  value = []
  items = [x for x in inp.split(",")]
  for d in items:
    
    value.append(str(int(math.sqrt(2 * c * float(d) / h))))
  return value

log = exemp("100,150,180")
print(log)
# Out:
# ['18', '22', '24']

# %%
# ЗАДАЧА 7
# Уровень: Средний

# Условие:
# Напишите программу, которая принимает 2 числа X, Y и генерирует двумерный массив, в котором значение по индексу i,j равно i*j.

# Пример ввода: "3,5"
# Результат: [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]

# Подсказка:
# Используйте вложенные циклы и генераторы списков.

input_str = "3,5"
dimensions = [int(x) for x in input_str.split(',')]
rowNum = dimensions[0]
colNum = dimensions[1]
multilist = [[0 for col in range(colNum)] for row in range(rowNum)]
for row in range(rowNum):
    for col in range(colNum):
        multilist[row][col] = row * col
print (multilist)
# Out:
# [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]

# %%
# ЗАДАЧА 8
# Уровень: Средний

# Условие:
# Программа принимает слова, разделённые запятой, и выводит их в алфавитном порядке.

# Пример ввода: without,hello,bag,world
# Результат: bag,hello,without,world

# Подсказка:
# Используйте метод sort().

word = "without,hello,bag,world"
items = [x for x in word.split(',')]
items.sort()
print (','.join(items))
# Out:
# bag,hello,without,world

# %%
# ЗАДАЧА 9
# Уровень: Средний

# Условие:
# Программа принимает несколько строк и выводит их, преобразовав все буквы в верхний регистр.

# Пример ввода:
# Hello world
# Practice makes perfect

word = "Hello world"

lines = []
while True:
    s = input()
    if s:
        lines.append(s.upper())
    else:
        break
for sentence in lines:
    print (sentence)
# Out:
# HTRTIUIRUTIL DJSAKLDS;JF DJSFA;LDSJF

# %%
# ЗАДАЧА 10
# Уровень: Средний

# Условие:
# Программа принимает строку слов, разделённых пробелами. Нужно удалить дубликаты и отсортировать результат по алфавиту.

# Пример ввода: hello world and practice makes perfect and hello world again
# Результат: again and hello makes perfect practice world

# Подсказка:
# Используйте set() и sorted().

w = "hello world and practice makes perfect and hello world again"
words = [word for word in w.split(" ")]
print (" ".join(sorted(list(set(words)))))
# Out:
# again and hello makes perfect practice world

# %%
# ЗАДАЧА 11
# Уровень: Средний

# Условие:
# Программа принимает 4-битные бинарные числа, разделённые запятой, и выводит только те, которые делятся на 5.

# Пример ввода: 0100,0011,1010,1001
# Результат: 1010

st_bin = "0100,0011,1010,1001"

value = []
items = [x for x in st_bin.split(',')]
for p in items:
    intp = int(p, 2)
    if not intp % 5:
        value.append(p)
print (','.join(value))
# Out:
# 1010

# %%
# ЗАДАЧА 12
# Уровень: Средний

# Условие:
# Найти все числа от 1000 до 3000 (включительно), у которых все цифры — чётные.

values = []
for i in range(1000, 3001):
    s = str(i)
    if (int(s[0]) % 2 == 0) and (int(s[1]) % 2 == 0) and (int(s[2]) % 2 == 0) and (int(s[3]) % 2 == 0):
        values.append(s)
print (",".join(values))
# Out:
# 2000,2002,2004,2006,2008,2020,2022,2024,2026,2028,2040,2042,2044,2046,2048,2060,2062,2064,2066,2068,2080,2082,2084,2086,2088,2200,2202,2204,2206,2208,2220,2222,2224,2226,2228,2240,2242,2244,2246,2248,2260,2262,2264,2266,2268,2280,2282,2284,2286,2288,2400,2402,2404,2406,2408,2420,2422,2424,2426,2428,2440,2442,2444,2446,2448,2460,2462,2464,2466,2468,2480,2482,2484,2486,2488,2600,2602,2604,2606,2608,2620,2622,2624,2626,2628,2640,2642,2644,2646,2648,2660,2662,2664,2666,2668,2680,2682,2684,2686,2688,2800,2802,2804,2806,2808,2820,2822,2824,2826,2828,2840,2842,2844,2846,2848,2860,2862,2864,2866,2868,2880,2882,2884,2886,2888

# %%
# ЗАДАЧА 13
# Уровень: Средний

# Условие:
# Программа принимает строку и подсчитывает количество букв и цифр.

# Пример ввода: hello world! 123
# Результат:
# LETTERS 10
# DIGITS 3

st = "hello world! 123"
result = []

d = {"DIGITS": 0, "LETTERS": 0}
for c in st:
    if c.isdigit():
        d["DIGITS"] = +1
    elif c.isalpha():
        d["LETTERS"] += 1
print ("LETTERS", d["LETTERS"])
print ("DIGITS", d["DIGITS"])
# Out:
# LETTERS 10
# DIGITS 1

# %%
# ЗАДАЧА 14
# Уровень: Средний

# Условие:
# Программа принимает строку и подсчитывает количество букв в верхнем и нижнем регистре.

# Пример ввода: Hello world!
# Результат:
# UPPER CASE 1
# LOWER CASE 9

st = "Hello world!"
result = {"Upp": 0, "Low": 0}

for char in st:
  if char.isupper():
    result["Upp"] += 1
  elif char.islower():
    result["Low"] += 1
print(result)
# Out:
# {'Upp': 1, 'Low': 9}

# %%
# ЗАДАЧА 15
# Уровень: Средний

# Условие:
# Вычислить значение выражения: a + aa + aaa + aaaa, где a — заданная цифра.

# Пример ввода: 9
# Результат: 11106

a = input()
n1 = int("%s" % a)
n2 = int("%s%s" % (a, a))
n3 = int("%s%s%s" % (a, a, a))
n4 = int("%s%s%s%s" % (a, a, a, a))
print (n1 + n2 + n3 + n4)
# Out:
# 11106
